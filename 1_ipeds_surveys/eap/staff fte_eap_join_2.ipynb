# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
eap_2002 = pd.read_csv('eap2002.csv',low_memory=False)
eap_2002 = eap_2002.fillna(0)

eap_2002.info()

functcd = [10,15,16,17,22]
eap_2002 = eap_2002[(eap_2002['fstat']==0) & (eap_2002['functcd'].isin(functcd))]

eap_2002_grouped = eap_2002.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2002_grouped.columns = ['total']
eap_2002_grouped = eap_2002_grouped.reset_index()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485227 entries, 0 to 485226
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   unitid    485227 non-null  int64
#  1   eaprectp  485227 non-null  int64
#  2   ftpt      485227 non-null  int64
#  3   functcd   485227 non-null  int64
#  4   fstat     485227 non-null  int64
#  5   xeaptyp   485227 non-null  object
#  6   eaptyp    485227 non-null  int64
#  7   xeapmed   485227 non-null  object
#  8   eapmed    485227 non-null  int64
#  9   xeaptot   485227 non-null  object
#  10  eaptot    485227 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 40.7+ MB

# %%
n = len(pd.unique(eap_2002_grouped['unitid']))
print(n)
# Out:
# 6498

# %%
double = eap_2002_grouped.groupby(['functcd','ftpt']).agg({'unitid':['nunique']})
print(double)
# Out:
#               unitid
#              nunique
# functcd ftpt
# 10      1       6498
#         2       6471
#         3       5791
# 15      1       6095
#         2       6019
#         3       1555
# 16      1       4893
#         2       4691
#         3       2997
# 17      1       5828
#         2       5580
#         3       4409
# 22      1       6406
#         2       6155
#         3       5322

# %%
eap_2002_grouped.head()
# Out:
#    unitid  functcd  ftpt  total
# 0  100654       10     1   1218
# 1  100654       10     2   1014
# 2  100654       10     3    204
# 3  100654       15     1     38
# 4  100654       15     2     38

# %%
eap_2002_pivot = pd.pivot_table(eap_2002_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2002_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2002_pivot.columns]
eap_2002_pivot =eap_2002_pivot.reset_index()
eap_2002_pivot['year'] = eap_2002_pivot['year'] = '2002'
eap_2002_pivot = eap_2002_pivot.fillna(0)
eap_2002_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1218.0      1014.0       204.0        38.0        38.0
# 1  100663      8804.0      7220.0      1584.0       231.0       223.0
# 2  100690        43.0        42.0         1.0         8.0         8.0
# 3  100706      1242.0      1042.0       200.0        57.0        57.0
# 4  100724      1077.0       824.0       253.0        46.0        46.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       399.0       296.0       103.0       405.0       388.0
# 1         8.0      2391.0      1950.0       441.0      3257.0      2399.0
# 2         0.0         4.0         4.0         0.0        21.0        20.0
# 3         0.0       387.0       380.0         7.0       324.0       318.0
# 4         0.0       178.0       146.0        32.0       472.0       401.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
#eap_2002_pivot['total_10_check'] = eap_2002_pivot['total_10_3'] + eap_2002_pivot['total_10_2']
#eap_2002_pivot_check = eap_2002_pivot[eap_2002_pivot['total_10_check'] != eap_2002_pivot['total_10_1']]
#eap_2002_pivot_check.head()

# %%
eap_2003 = pd.read_csv('eap2003.csv',low_memory=False)
eap_2003.info()

#functcd = [10,15,16,17,22]
#eap_2003 = eap_2003[(eap_2003['fstat']==0) & (eap_2003['functcd'].isin(functcd))]


#eap_2003_grouped = eap_2003.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
#eap_2003_grouped.columns = ['total']
#eap_2003_grouped = eap_2003_grouped.reset_index()
#eap_2003_grouped.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494252 entries, 0 to 494251
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   unitid    494252 non-null  int64
#  1   eaprectp  494252 non-null  int64
#  2   ftpt      494252 non-null  int64
#  3   functcd   494252 non-null  int64
#  4   fstat     494252 non-null  int64
#  5   xeaptyp   494252 non-null  object
#  6   eaptyp    494252 non-null  int64
#  7   xeapmed   494252 non-null  object
#  8   eapmed    494252 non-null  int64
#  9   xeaptot   494252 non-null  object
#  10  eaptot    494252 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 41.5+ MB

# %%
eap_2003_pivot = pd.pivot_table(eap_2003_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2003_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2003_pivot.columns]
eap_2003_pivot =eap_2003_pivot.reset_index()
eap_2003_pivot = eap_2003_pivot.fillna(0)
eap_2003_pivot['year'] = eap_2003_pivot['year'] = '2003'
eap_2003_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1194.0       982.0       212.0        40.0        40.0
# 1  100663     10242.0      7642.0      2600.0       236.0       222.0
# 2  100690       106.0        85.0        21.0        11.0        11.0
# 3  100706      1272.0      1049.0       223.0        57.0        57.0
# 4  100724      1124.0       845.0       279.0        43.0        43.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       390.0       275.0       115.0       380.0       368.0
# 1        14.0      3334.0      2689.0       645.0      4393.0      2672.0
# 2         0.0         8.0         8.0         0.0        11.0         4.0
# 3         0.0       398.0       390.0         8.0       319.0       309.0
# 4         0.0       184.0       165.0        19.0       487.0       402.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2004 = pd.read_csv('eap2004_rv.csv',low_memory=False)
eap_2004.columns = eap_2004.columns.str.lower()
eap_2004.columns = eap_2004.columns.str.replace(' ', '')
eap_2004.info()

functcd = [10,15,16,17,22]
eap_2004 = eap_2004[(eap_2004['fstat']==0) & (eap_2004['functcd'].isin(functcd))]


eap_2004_grouped = eap_2004.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2004_grouped.columns = ['total']
eap_2004_grouped = eap_2004_grouped.reset_index()
eap_2004_grouped.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499209 entries, 0 to 499208
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   unitid    499209 non-null  int64
#  1   eaprectp  499209 non-null  int64
#  2   ftpt      499209 non-null  int64
#  3   functcd   499209 non-null  int64
#  4   fstat     499209 non-null  int64
#  5   xeaptyp   499209 non-null  object
#  6   eaptyp    499209 non-null  int64
#  7   xeapmed   499209 non-null  object
#  8   eapmed    499209 non-null  int64
#  9   xeaptot   499209 non-null  object
#  10  eaptot    499209 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 41.9+ MB
#    unitid  functcd  ftpt  total
# 0  100654       10     1   1251
# 1  100654       10     2   1028
# 2  100654       10     3    223
# 3  100654       15     1     45
# 4  100654       15     2     45

# %%
eap_2004_pivot = pd.pivot_table(eap_2004_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2004_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2004_pivot.columns]
eap_2004_pivot =eap_2004_pivot.reset_index()
eap_2004_pivot['year'] = eap_2004_pivot['year'] = '2004'
eap_2004_pivot = eap_2004_pivot.fillna(0)
eap_2004_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1251.0      1028.0       223.0        45.0        45.0
# 1  100663     10123.0      7614.0      2509.0       205.0       196.0
# 2  100690       109.0        86.0        23.0        11.0        11.0
# 3  100706      1273.0      1075.0       198.0        57.0        57.0
# 4  100724      1100.0       830.0       270.0        46.0        46.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       422.0       309.0       113.0       379.0       367.0
# 1         9.0      3380.0      2717.0       663.0      4457.0      2812.0
# 2         0.0         9.0         9.0         0.0        15.0         6.0
# 3         0.0       440.0       427.0        13.0       321.0       304.0
# 4         0.0       172.0       150.0        22.0       483.0       402.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2005 = pd.read_csv('eap2005_rv.csv',low_memory=False)
eap_2005.columns = eap_2005.columns.str.lower()
eap_2005.columns = eap_2005.columns.str.replace(' ', '')

#eap_2005.info()

functcd = [10,15,16,17,22]
eap_2005 = eap_2005[(eap_2005['fstat']==0) & (eap_2005['functcd'].isin(functcd))]

eap_2005_grouped = eap_2005.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2005_grouped.columns = ['total']
eap_2005_grouped = eap_2005_grouped.reset_index()
eap_2005_grouped.head()
# Out:
#    unitid  functcd  ftpt  total
# 0  100654       10     1   1261
# 1  100654       10     2   1083
# 2  100654       10     3    178
# 3  100654       15     1     44
# 4  100654       15     2     44

# %%
eap_2005_pivot = pd.pivot_table(eap_2005_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2005_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2005_pivot.columns]
eap_2005_pivot =eap_2005_pivot.reset_index()
eap_2005_pivot['year'] = eap_2005_pivot['year'] = '2005'
eap_2005_pivot = eap_2005_pivot.fillna(0)
eap_2005_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1261.0      1083.0       178.0        44.0        44.0
# 1  100663      9917.0      7748.0      2169.0       223.0       216.0
# 2  100690       112.0        88.0        24.0        13.0        13.0
# 3  100706      1320.0      1118.0       202.0        57.0        57.0
# 4  100724      1128.0       832.0       296.0        49.0        49.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       434.0       345.0        89.0       384.0       373.0
# 1         7.0      3170.0      2797.0       373.0      4410.0      2778.0
# 2         0.0        10.0        10.0         0.0        15.0         8.0
# 3         0.0       450.0       445.0         5.0       332.0       317.0
# 4         0.0       182.0       153.0        29.0       489.0       402.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2006 = pd.read_csv('eap2006_rv.csv',low_memory=False)
eap_2006.columns = eap_2006.columns.str.lower()
eap_2006.columns = eap_2006.columns.str.replace(' ', '')

#eap_2006.info()

functcd = [10,15,16,17,22]
eap_2006 = eap_2006[(eap_2006['fstat']==0) & (eap_2006['functcd'].isin(functcd))]

eap_2006_grouped = eap_2006.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2006_grouped.columns = ['total']
eap_2006_grouped = eap_2006_grouped.reset_index()
eap_2006_grouped.head()
# Out:
#    unitid  functcd  ftpt  total
# 0  100654       10     1   1238
# 1  100654       10     2   1076
# 2  100654       10     3    162
# 3  100654       15     1     47
# 4  100654       15     2     47

# %%
eap_2006_pivot = pd.pivot_table(eap_2006_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2006_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2006_pivot.columns]
eap_2006_pivot =eap_2006_pivot.reset_index()
eap_2006_pivot['year'] = eap_2006_pivot['year'] = '2006'
eap_2006_pivot = eap_2006_pivot.fillna(0)
eap_2006_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1238.0      1076.0       162.0        47.0        47.0
# 1  100663      9774.0      7892.0      1882.0       229.0       222.0
# 2  100690       130.0        85.0        45.0        13.0        13.0
# 3  100706      1349.0      1167.0       182.0        64.0        64.0
# 4  100724      1099.0       843.0       256.0        43.0        43.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       432.0       351.0        81.0       368.0       359.0
# 1         7.0      3229.0      2904.0       325.0      4154.0      2762.0
# 2         0.0        13.0        13.0         0.0        16.0        10.0
# 3         0.0       489.0       484.0         5.0       330.0       317.0
# 4         0.0       184.0       162.0        22.0       473.0       407.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2007 = pd.read_csv('eap2007_rv.csv',low_memory=False)
eap_2007.columns = eap_2007.columns.str.lower()
eap_2007.columns = eap_2007.columns.str.replace(' ', '')

#eap_2007.info()

functcd = [10,15,16,17,22]
eap_2007 = eap_2007[(eap_2007['fstat']==0) & (eap_2007['functcd'].isin(functcd))]

eap_2007_grouped = eap_2007.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2007_grouped.columns = ['total']
eap_2007_grouped = eap_2007_grouped.reset_index()

eap_2007_grouped.head()
# Out:
#    unitid  functcd  ftpt  total
# 0  100654       10     1   1234
# 1  100654       10     2   1063
# 2  100654       10     3    171
# 3  100654       15     1     48
# 4  100654       15     2     48

# %%
eap_2007_pivot = pd.pivot_table(eap_2007_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2007_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2007_pivot.columns]
eap_2007_pivot =eap_2007_pivot.reset_index()
eap_2007_pivot['year'] = eap_2007_pivot['year'] = '2007'
eap_2007_pivot = eap_2007_pivot.fillna(0)

eap_2007_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1234.0      1063.0       171.0        48.0        48.0
# 1  100663      9518.0      7864.0      1654.0       262.0       256.0
# 2  100690       127.0        86.0        41.0        13.0        13.0
# 3  100706      1405.0      1204.0       201.0        64.0        64.0
# 4  100724      1152.0       878.0       274.0        45.0        44.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       437.0       353.0        84.0       367.0       350.0
# 1         6.0      3243.0      2889.0       354.0      3815.0      2670.0
# 2         0.0        13.0        13.0         0.0        15.0        10.0
# 3         0.0       528.0       522.0         6.0       328.0       313.0
# 4         1.0       194.0       173.0        21.0       503.0       422.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2008 = pd.read_csv('eap2008_rv.csv',low_memory=False)
eap_2008.columns = eap_2008.columns.str.lower()
eap_2008.columns = eap_2008.columns.str.replace(' ', '')

#eap_2008.info()

functcd = [10,15,16,17,22]
eap_2008 = eap_2008[(eap_2008['fstat']==0) & (eap_2008['functcd'].isin(functcd))]

eap_2008_grouped = eap_2008.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2008_grouped.columns = ['total']
eap_2008_grouped = eap_2008_grouped.reset_index()
eap_2008_grouped.head()
# Out:
#    unitid  functcd  ftpt  total
# 0  100654       10     1   1217
# 1  100654       10     2   1070
# 2  100654       10     3    147
# 3  100654       15     1     46
# 4  100654       15     2     46

# %%
eap_2008_pivot = pd.pivot_table(eap_2008_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2008_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2008_pivot.columns]
eap_2008_pivot =eap_2008_pivot.reset_index()
eap_2008_pivot['year'] = eap_2008_pivot['year'] = '2008'
eap_2008_pivot = eap_2008_pivot.fillna(0)
eap_2008_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1217.0      1070.0       147.0        46.0        46.0
# 1  100663      9388.0      7881.0      1507.0       265.0       260.0
# 2  100690       101.0        79.0        22.0        12.0        12.0
# 3  100706      1438.0      1258.0       180.0        65.0        65.0
# 4  100724      1131.0       872.0       259.0        43.0        43.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       422.0       360.0        62.0       369.0       355.0
# 1         5.0      3255.0      2912.0       343.0      3667.0      2661.0
# 2         0.0        12.0        12.0         0.0        15.0        11.0
# 3         0.0       593.0       585.0         8.0       310.0       295.0
# 4         0.0       188.0       171.0        17.0       493.0       415.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2009 = pd.read_csv('eap2009_rv.csv',low_memory=False)
eap_2009.columns = eap_2009.columns.str.lower()
eap_2009.columns = eap_2009.columns.str.replace(' ', '')

#eap_2009.info()

functcd = [10,15,16,17,22]
eap_2009 = eap_2009[(eap_2009['fstat']==0) & (eap_2009['functcd'].isin(functcd))]

eap_2009_grouped = eap_2009.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2009_grouped.columns = ['total']
eap_2009_grouped = eap_2009_grouped.reset_index()
eap_2009_grouped.head()

eap_2009_pivot = pd.pivot_table(eap_2009_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2009_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2009_pivot.columns]
eap_2009_pivot =eap_2009_pivot.reset_index()
eap_2009_pivot['year'] = eap_2009_pivot['year'] = '2009'
eap_2009_pivot = eap_2009_pivot.fillna(0)
eap_2009_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654      1191.0      1036.0       155.0        44.0        43.0
# 1  100663      9048.0      7583.0      1465.0       258.0       252.0
# 2  100690       118.0        77.0        41.0        12.0        12.0
# 3  100706      1413.0      1236.0       177.0        64.0        64.0
# 4  100724      1130.0       871.0       259.0        42.0        42.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         1.0       418.0       350.0        68.0       342.0       329.0
# 1         6.0      3209.0      2838.0       371.0      3405.0      2466.0
# 2         0.0        14.0        14.0         0.0        15.0        11.0
# 3         0.0       604.0       596.0         8.0       278.0       263.0
# 4         0.0       216.0       194.0        22.0       464.0       394.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2010 = pd.read_csv('eap2010_rv.csv',low_memory=False)
eap_2010.columns = eap_2010.columns.str.lower()
eap_2010.columns = eap_2010.columns.str.replace(' ', '')

#eap_2010.info()

functcd = [10,15,16,17,22]
eap_2010 = eap_2010[(eap_2010['fstat']==0) & (eap_2010['functcd'].isin(functcd))]


eap_2010_grouped = eap_2010.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2010_grouped.columns = ['total']
eap_2010_grouped = eap_2010_grouped.reset_index()
eap_2010_grouped.head()

eap_2010_pivot = pd.pivot_table(eap_2010_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2010_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2010_pivot.columns]
eap_2010_pivot =eap_2010_pivot.reset_index()
eap_2010_pivot['year'] = eap_2010_pivot['year'] = '2010'
eap_2010_pivot = eap_2010_pivot.fillna(0)
eap_2010_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654       992.0       875.0       117.0        39.0        39.0
# 1  100663      9050.0      7557.0      1493.0       235.0       227.0
# 2  100690       118.0        75.0        43.0        15.0        15.0
# 3  100706      1483.0      1284.0       199.0        55.0        55.0
# 4  100724      1160.0       896.0       264.0        58.0        58.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       363.0       359.0         4.0       242.0       187.0
# 1         8.0      3232.0      2851.0       381.0      3392.0      2435.0
# 2         0.0        12.0        12.0         0.0        13.0         9.0
# 3         0.0       646.0       642.0         4.0       294.0       275.0
# 4         0.0       224.0       205.0        19.0       471.0       380.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
eap_2011 = pd.read_csv('eap2011_rv.csv',low_memory=False)
eap_2011.columns = eap_2011.columns.str.lower()
eap_2011.columns = eap_2011.columns.str.replace(' ', '')

#eap_2011.info()

functcd = [10,15,16,17,22]
eap_2011 = eap_2011[(eap_2011['fstat']==0) & (eap_2011['functcd'].isin(functcd))]

eap_2011_grouped = eap_2011.groupby(['unitid','functcd','ftpt']).agg({'eaptot':['max']})
eap_2011_grouped.columns = ['total']
eap_2011_grouped = eap_2011_grouped.reset_index()
eap_2011_grouped.head()

eap_2011_pivot = pd.pivot_table(eap_2011_grouped, index=['unitid'],columns=['functcd','ftpt'],values=['total'])
eap_2011_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2011_pivot.columns]
eap_2011_pivot =eap_2011_pivot.reset_index()
eap_2011_pivot['year'] = eap_2011_pivot['year'] = '2011'
eap_2011_pivot = eap_2011_pivot.fillna(0)
eap_2011_pivot.head()
# Out:
#    unitid  total_10_1  total_10_2  total_10_3  total_15_1  total_15_2  \
# 0  100654       984.0       830.0       154.0        33.0        33.0
# 1  100663      9175.0      7531.0      1644.0       237.0       229.0
# 2  100690       113.0        77.0        36.0        12.0        12.0
# 3  100706      1529.0      1325.0       204.0        61.0        61.0
# 4  100724      1082.0       897.0       185.0        48.0        48.0
#
#    total_15_3  total_16_1  total_16_2  total_16_3  total_17_1  total_17_2  \
# 0         0.0       374.0       371.0         3.0       236.0       161.0
# 1         8.0      3388.0      2880.0       508.0      3322.0      2364.0
# 2         0.0        13.0        13.0         0.0        14.0         5.0
# 3         0.0       686.0       675.0        11.0       289.0       275.0
# 4         0.0       233.0       224.0         9.0       378.0       369.0
#
#    total_17_3  total_22_1  total_22_2  total_22_3  year
# ...

# %%
merge = pd.concat([eap_2002_pivot,eap_2003_pivot,eap_2004_pivot,eap_2005_pivot,eap_2006_pivot,eap_2007_pivot,eap_2008_pivot,eap_2009_pivot,eap_2010_pivot,eap_2011_pivot],ignore_index=False)
merge = merge[['unitid','year','total_10_1','total_10_2','total_10_3','total_22_1','total_22_2','total_22_3']]
merge = merge.fillna(0)

merge['total non instruction'] = merge['total_10_1'] - merge['total_22_1']
merge['total non instruction ft'] = merge['total_10_2'] - merge['total_22_2']
merge['total non instruction pt'] = merge['total_10_3'] - merge['total_22_3']

merge['total non instruction staff fte'] = merge['total non instruction ft'] + (merge['total non instruction pt']*.333).round(0)
merge['total staff fte'] = merge['total_10_2'] + (merge['total_10_3']*.333).round(0)
merge['total instruction staff fte'] = merge['total_22_2'] + (merge['total_22_3']*.333).round(0)

merge = merge.rename(columns={'total_10_1':'total staff','total_10_2':'total staff ft','total_10_3':'total staff pt','total_22_1':'total instruction staff','total_22_2':'total instruction ft','total_22_3':'total instruction pt'})

merge = merge[['unitid','year','total staff','total staff ft','total staff pt','total staff fte','total instruction staff','total instruction ft','total instruction pt','total instruction staff fte','total non instruction','total non instruction ft','total non instruction pt','total non instruction staff fte']]

merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68828 entries, 0 to 7500
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   unitid                           68828 non-null  int64
#  1   year                             68828 non-null  object
#  2   total staff                      68828 non-null  float64
#  3   total staff ft                   68828 non-null  float64
#  4   total staff pt                   68828 non-null  float64
#  5   total staff fte                  68828 non-null  float64
#  6   total instruction staff          68828 non-null  float64
#  7   total instruction ft             68828 non-null  float64
#  8   total instruction pt             68828 non-null  float64
#  9   total instruction staff fte      68828 non-null  float64
#  10  total non instruction            68828 non-null  float64
# ...

# %%
eap_2012 = pd.read_csv('eap2012_rv.csv',low_memory=False)
eap_2012.columns = eap_2012.columns.str.lower()

eap_2012.head()

eapcat = [10000,20000]
eap_2012 = eap_2012[(eap_2012['facstat']==0) & (eap_2012['eapcat'].isin(eapcat))]

eap_2012_grouped = eap_2012.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2012_grouped.columns = ['total','total ft','total pt']
eap_2012_grouped = eap_2012_grouped.reset_index()
eap_2012_grouped.head()

eap_2012_pivot = pd.pivot_table(eap_2012_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2012_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2012_pivot.columns]
eap_2012_pivot =eap_2012_pivot.reset_index()
eap_2012_pivot['year'] = eap_2012_pivot['year'] = '2012'
eap_2012_pivot = eap_2012_pivot.fillna(0)
eap_2012_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654       1024.0        466.0           791.0           314.0
# 1  100663       9218.0       2274.0          7554.0          2110.0
# 2  100690        100.0         66.0            69.0            38.0
# 3  100706       1521.0        488.0          1329.0           314.0
# 4  100724       1192.0        429.0           939.0           276.0
#
#    total pt_10000  total pt_20000  year
# 0           233.0           152.0  2012
# 1          1664.0           164.0  2012
# 2            31.0            28.0  2012
# 3           192.0           174.0  2012
# 4           253.0           153.0  2012

# %%
eap_2013 = pd.read_csv('eap2013_rv.csv',low_memory=False)
eap_2013.columns = eap_2013.columns.str.lower()

eap_2013.head()

eapcat = [10000,20000]
eap_2013 = eap_2013[(eap_2013['facstat']==0) & (eap_2013['eapcat'].isin(eapcat))]

eap_2013_grouped = eap_2013.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2013_grouped.columns = ['total','total ft','total pt']
eap_2013_grouped = eap_2013_grouped.reset_index()
eap_2013_grouped.head()

eap_2013_pivot = pd.pivot_table(eap_2013_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2013_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2013_pivot.columns]
eap_2013_pivot =eap_2013_pivot.reset_index()
eap_2013_pivot['year'] = eap_2013_pivot['year'] = '2013'
eap_2013_pivot = eap_2013_pivot.fillna(0)
eap_2013_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        871.0        448.0           793.0           371.0
# 1  100663       9224.0       2429.0          7670.0          2244.0
# 2  100690         97.0         61.0            72.0            41.0
# 3  100706       1529.0        476.0          1348.0           312.0
# 4  100724       1180.0        415.0           931.0           278.0
#
#    total pt_10000  total pt_20000  year
# 0            78.0            77.0  2013
# 1          1554.0           185.0  2013
# 2            25.0            20.0  2013
# 3           181.0           164.0  2013
# 4           249.0           137.0  2013

# %%
eap_2014 = pd.read_csv('eap2014_rv.csv',low_memory=False)
eap_2014.columns = eap_2014.columns.str.lower()

eap_2014.head()

eapcat = [10000,20000]
eap_2014 = eap_2014[(eap_2014['facstat']==0) & (eap_2014['eapcat'].isin(eapcat))]

eap_2014_grouped = eap_2014.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2014_grouped.columns = ['total','total ft','total pt']
eap_2014_grouped = eap_2014_grouped.reset_index()
eap_2014_grouped.head()

eap_2014_pivot = pd.pivot_table(eap_2014_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2014_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2014_pivot.columns]
eap_2014_pivot =eap_2014_pivot.reset_index()
eap_2014_pivot['year'] = eap_2014_pivot['year'] = '2014'
eap_2014_pivot = eap_2014_pivot.fillna(0)
eap_2014_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        860.0        256.0           761.0           243.0
# 1  100663       9211.0       2392.0          7667.0          2210.0
# 2  100690         83.0         50.0            60.0            30.0
# 3  100706       1531.0        479.0          1332.0           298.0
# 4  100724       1121.0        431.0           895.0           271.0
#
#    total pt_10000  total pt_20000  year
# 0            99.0            13.0  2014
# 1          1544.0           182.0  2014
# 2            23.0            20.0  2014
# 3           199.0           181.0  2014
# 4           226.0           160.0  2014

# %%
eap_2015 = pd.read_csv('eap2015_rv.csv',low_memory=False)
eap_2015.columns = eap_2015.columns.str.lower()

eap_2015.head()

eapcat = [10000,20000]
eap_2015 = eap_2015[(eap_2015['facstat']==0) & (eap_2015['eapcat'].isin(eapcat))]

eap_2015_grouped = eap_2015.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2015_grouped.columns = ['total','total ft','total pt']
eap_2015_grouped = eap_2015_grouped.reset_index()
eap_2015_grouped.head()

eap_2015_pivot = pd.pivot_table(eap_2015_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2015_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2015_pivot.columns]
eap_2015_pivot =eap_2015_pivot.reset_index()
eap_2015_pivot['year'] = eap_2015_pivot['year'] = '2015'
eap_2015_pivot = eap_2015_pivot.fillna(0)
eap_2015_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        963.0        352.0           766.0           246.0
# 1  100663       9385.0       2458.0          7809.0          2268.0
# 2  100690         70.0         36.0            67.0            36.0
# 3  100706       1521.0        520.0          1304.0           321.0
# 4  100724       1042.0        415.0           830.0           260.0
#
#    total pt_10000  total pt_20000  year
# 0           197.0           106.0  2015
# 1          1576.0           190.0  2015
# 2             3.0             0.0  2015
# 3           217.0           199.0  2015
# 4           212.0           155.0  2015

# %%
eap_2016 = pd.read_csv('eap2016_rv.csv',low_memory=False)
eap_2016.columns = eap_2016.columns.str.lower()

eap_2016.head()

eapcat = [10000,20000]
eap_2016 = eap_2016[(eap_2016['facstat']==0) & (eap_2016['eapcat'].isin(eapcat))]

eap_2016_grouped = eap_2016.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2016_grouped.columns = ['total','total ft','total pt']
eap_2016_grouped = eap_2016_grouped.reset_index()
eap_2016_grouped.head()

eap_2016_pivot = pd.pivot_table(eap_2016_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2016_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2016_pivot.columns]
eap_2016_pivot =eap_2016_pivot.reset_index()
eap_2016_pivot['year'] = eap_2016_pivot['year'] = '2016'
eap_2016_pivot = eap_2016_pivot.fillna(0)
eap_2016_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        981.0        355.0           779.0           260.0
# 1  100663       9483.0       2503.0          7948.0          2274.0
# 2  100690         69.0         32.0            66.0            32.0
# 3  100706       1502.0        513.0          1303.0           327.0
# 4  100724       1047.0        409.0           819.0           255.0
#
#    total pt_10000  total pt_20000  year
# 0           202.0            95.0  2016
# 1          1535.0           229.0  2016
# 2             3.0             0.0  2016
# 3           199.0           186.0  2016
# 4           228.0           154.0  2016

# %%
eap_2017 = pd.read_csv('eap2017_rv.csv',low_memory=False)
eap_2017.columns = eap_2017.columns.str.lower()

eap_2017.head()

eapcat = [10000,20000]
eap_2017 = eap_2017[(eap_2017['facstat']==0) & (eap_2017['eapcat'].isin(eapcat))]

eap_2017_grouped = eap_2017.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2017_grouped.columns = ['total','total ft','total pt']
eap_2017_grouped = eap_2017_grouped.reset_index()
eap_2017_grouped.head()

eap_2017_pivot = pd.pivot_table(eap_2017_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2017_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2017_pivot.columns]
eap_2017_pivot =eap_2017_pivot.reset_index()
eap_2017_pivot['year'] = eap_2017_pivot['year'] = '2017'
eap_2017_pivot = eap_2017_pivot.fillna(0)
eap_2017_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654       1017.0        366.0           783.0           256.0
# 1  100663       9738.0       2563.0          8159.0          2336.0
# 2  100690         67.0         33.0            60.0            33.0
# 3  100706       1557.0        549.0          1344.0           346.0
# 4  100724       1100.0        450.0           778.0           235.0
#
#    total pt_10000  total pt_20000  year
# 0           234.0           110.0  2017
# 1          1579.0           227.0  2017
# 2             7.0             0.0  2017
# 3           213.0           203.0  2017
# 4           322.0           215.0  2017

# %%
eap_2018 = pd.read_csv('eap2018_rv.csv',low_memory=False)
eap_2018.columns = eap_2018.columns.str.lower()

eap_2018.head()

eapcat = [10000,20000]
eap_2018 = eap_2018[(eap_2018['facstat']==0) & (eap_2018['eapcat'].isin(eapcat))]

eap_2018_grouped = eap_2018.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2018_grouped.columns = ['total','total ft','total pt']
eap_2018_grouped = eap_2018_grouped.reset_index()
eap_2018_grouped.head()

eap_2018_pivot = pd.pivot_table(eap_2018_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2018_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2018_pivot.columns]
eap_2018_pivot =eap_2018_pivot.reset_index()
eap_2018_pivot['year'] = eap_2018_pivot['year'] = '2018'
eap_2018_pivot = eap_2018_pivot.fillna(0)
eap_2018_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        977.0        354.0           794.0           259.0
# 1  100663      10231.0       2829.0          8427.0          2444.0
# 2  100690         75.0         33.0            61.0            33.0
# 3  100706       1557.0        544.0          1347.0           347.0
# 4  100724       1063.0        413.0           786.0           231.0
#
#    total pt_10000  total pt_20000  year
# 0           183.0            95.0  2018
# 1          1804.0           385.0  2018
# 2            14.0             0.0  2018
# 3           210.0           197.0  2018
# 4           277.0           182.0  2018

# %%
eap_2019 = pd.read_csv('eap2019_rv.csv',low_memory=False)
eap_2019.columns = eap_2019.columns.str.lower()

eap_2019.head()

eapcat = [10000,20000]
eap_2019 = eap_2019[(eap_2019['facstat']==0) & (eap_2019['eapcat'].isin(eapcat))]

eap_2019_grouped = eap_2019.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2019_grouped.columns = ['total','total ft','total pt']
eap_2019_grouped = eap_2019_grouped.reset_index()
eap_2019_grouped.head()

eap_2019_pivot = pd.pivot_table(eap_2019_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2019_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2019_pivot.columns]
eap_2019_pivot =eap_2019_pivot.reset_index()
eap_2019_pivot['year'] = eap_2019_pivot['year'] = '2019'
eap_2019_pivot = eap_2019_pivot.fillna(0)
eap_2019_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        951.0        366.0           725.0           254.0
# 1  100663      10579.0       2917.0          8674.0          2523.0
# 2  100690         84.0         30.0            67.0            30.0
# 3  100706       1609.0        578.0          1384.0           363.0
# 4  100724        984.0        363.0           800.0           229.0
#
#    total pt_10000  total pt_20000  year
# 0           226.0           112.0  2019
# 1          1905.0           394.0  2019
# 2            17.0             0.0  2019
# 3           225.0           215.0  2019
# 4           184.0           134.0  2019

# %%
eap_2020 = pd.read_csv('eap2020_rv.csv',low_memory=False)
eap_2020.columns = eap_2020.columns.str.lower()

eap_2020.head()

eapcat = [10000,20000]
eap_2020 = eap_2020[(eap_2020['facstat']==0) & (eap_2020['eapcat'].isin(eapcat))]

eap_2020_grouped = eap_2020.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2020_grouped.columns = ['total','total ft','total pt']
eap_2020_grouped = eap_2020_grouped.reset_index()
eap_2020_grouped.head()

eap_2020_pivot = pd.pivot_table(eap_2020_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2020_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2020_pivot.columns]
eap_2020_pivot =eap_2020_pivot.reset_index()
eap_2020_pivot['year'] = eap_2020_pivot['year'] = '2020'
eap_2020_pivot = eap_2020_pivot.fillna(0)
eap_2020_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        918.0        372.0           762.0           262.0
# 1  100663      10093.0       2958.0          8496.0          2544.0
# 2  100690         78.0         46.0            67.0            35.0
# 3  100706       1592.0        538.0          1398.0           353.0
# 4  100724        919.0        341.0           767.0           226.0
#
#    total pt_10000  total pt_20000  year
# 0           156.0           110.0  2020
# 1          1597.0           414.0  2020
# 2            11.0            11.0  2020
# 3           194.0           185.0  2020
# 4           152.0           115.0  2020

# %%
eap_2021 = pd.read_csv('eap2021.csv',low_memory=False)
eap_2021.columns = eap_2021.columns.str.lower()

eap_2021.head()

eapcat = [10000,20000]
eap_2021 = eap_2021[(eap_2021['facstat']==0) & (eap_2021['eapcat'].isin(eapcat))]

eap_2021_grouped = eap_2021.groupby(['unitid','eapcat']).agg({'eaptot':['max'],'eapft':['max'],'eappt':['max']})
eap_2021_grouped.columns = ['total','total ft','total pt']
eap_2021_grouped = eap_2021_grouped.reset_index()
eap_2021_grouped.head()

eap_2021_pivot = pd.pivot_table(eap_2021_grouped, index=['unitid'],columns=['eapcat'],values=['total','total ft','total pt'])
eap_2021_pivot.columns = ['_'.join(str(s).strip() for s in col if s) for col in eap_2021_pivot.columns]
eap_2021_pivot =eap_2021_pivot.reset_index()
eap_2021_pivot['year'] = eap_2021_pivot['year'] = '2021'
eap_2021_pivot = eap_2021_pivot.fillna(0)
eap_2021_pivot.head()
# Out:
#    unitid  total_10000  total_20000  total ft_10000  total ft_20000  \
# 0  100654        787.0        306.0           640.0           211.0
# 1  100663      10372.0       3042.0          8638.0          2603.0
# 2  100690         76.0         44.0            66.0            34.0
# 3  100706       1662.0        549.0          1456.0           351.0
# 4  100724        882.0        331.0           760.0           221.0
#
#    total pt_10000  total pt_20000  year
# 0           147.0            95.0  2021
# 1          1734.0           439.0  2021
# 2            10.0            10.0  2021
# 3           206.0           198.0  2021
# 4           122.0           110.0  2021

# %%
merge2 = pd.concat([eap_2012_pivot,eap_2013_pivot,eap_2014_pivot,eap_2015_pivot,eap_2016_pivot,eap_2017_pivot,eap_2018_pivot,eap_2019_pivot,eap_2020_pivot,eap_2021_pivot],ignore_index=False)
merge2 = merge2.reset_index(drop=True)
merge2 = merge2.rename(columns={'total_10000':'total staff','total_20000':'total instruction staff','total ft_10000':'total staff ft','total ft_20000':'total instruction ft','total pt_10000':'total staff pt','total pt_20000':'total instruction pt'})
merge2 = merge2.fillna(0)

merge2['total non instruction'] = merge2['total staff'] - merge2['total instruction staff']
merge2['total non instruction ft'] = merge2['total staff ft'] - merge2['total instruction ft']
merge2['total non instruction pt'] = merge2['total staff pt'] - merge2['total instruction pt']

merge2['total staff fte'] = merge2['total staff ft'] + (merge2['total staff pt']*.333).round(0)
merge2['total instruction staff fte'] = merge2['total instruction ft'] + (merge2['total instruction pt']*.333).round(0)
merge2['total non instruction staff fte'] = merge2['total non instruction ft'] + (merge2['total non instruction pt']*.333).round(0)

merge2 = merge2[['unitid','year','total staff','total staff ft','total staff pt','total staff fte','total instruction staff','total instruction ft','total instruction pt','total instruction staff fte','total non instruction','total non instruction ft','total non instruction pt','total non instruction staff fte']]

merge2.info()

#merge2_grouped = merge2.groupby(['year']).agg({'unitid':['nunique']})
#print(merge2_grouped)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68107 entries, 0 to 68106
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   unitid                           68107 non-null  int64
#  1   year                             68107 non-null  object
#  2   total staff                      68107 non-null  float64
#  3   total staff ft                   68107 non-null  float64
#  4   total staff pt                   68107 non-null  float64
#  5   total staff fte                  68107 non-null  float64
#  6   total instruction staff          68107 non-null  float64
#  7   total instruction ft             68107 non-null  float64
#  8   total instruction pt             68107 non-null  float64
#  9   total instruction staff fte      68107 non-null  float64
#  10  total non instruction            68107 non-null  float64
# ...

# %%
eap_merge_master = pd.concat([merge,merge2],ignore_index=False)
eap_merge_master.info()

eap_merge_master_grouped = eap_merge_master.groupby(['year']).agg({'unitid':['nunique']})
print(eap_merge_master_grouped)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136935 entries, 0 to 68106
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   unitid                           136935 non-null  int64
#  1   year                             136935 non-null  object
#  2   total staff                      136935 non-null  float64
#  3   total staff ft                   136935 non-null  float64
#  4   total staff pt                   136935 non-null  float64
#  5   total staff fte                  136935 non-null  float64
#  6   total instruction staff          136935 non-null  float64
#  7   total instruction ft             136935 non-null  float64
#  8   total instruction pt             136935 non-null  float64
#  9   total instruction staff fte      136935 non-null  float64
#  10  total non instruction            136935 non-null  float64
# ...

# %%
eap_merge_master['unitid_year'] = eap_merge_master['unitid'].astype(str) + "_" + eap_merge_master['year'].astype(str)

# %%
eap_merge_master.isnull().sum()
# Out:
# unitid                             0
# year                               0
# total staff                        0
# total staff ft                     0
# total staff pt                     0
# total staff fte                    0
# total instruction staff            0
# total instruction ft               0
# total instruction pt               0
# total instruction staff fte        0
# total non instruction              0
# total non instruction ft           0
# total non instruction pt           0
# total non instruction staff fte    0
# unitid_year                        0
# dtype: int64

# %%
eap_merge_zero = eap_merge_master[eap_merge_master['total staff']==0]

#print(eap_merge_zero.groupby('year')['unitid'].count())

eap_merge_zero_drop = eap_merge_zero['unitid_year'].tolist()
print(eap_merge_zero_drop)

eap_merge_final = eap_merge_master[~eap_merge_master['unitid_year'].isin(eap_merge_zero_drop)]
# Out:
# []

# %%
eap_merge_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136935 entries, 0 to 68106
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   unitid                           136935 non-null  int64
#  1   year                             136935 non-null  object
#  2   total staff                      136935 non-null  float64
#  3   total staff ft                   136935 non-null  float64
#  4   total staff pt                   136935 non-null  float64
#  5   total staff fte                  136935 non-null  float64
#  6   total instruction staff          136935 non-null  float64
#  7   total instruction ft             136935 non-null  float64
#  8   total instruction pt             136935 non-null  float64
#  9   total instruction staff fte      136935 non-null  float64
#  10  total non instruction            136935 non-null  float64
# ...

# %%
eap_merge_final_zero_check = eap_merge_master[eap_merge_master['total staff fte']==0]

print(eap_merge_final_zero_check.groupby('year')['unitid'].count())

eap_merge_final_zero_check_drop = eap_merge_final_zero_check['unitid_year'].tolist()
print(eap_merge_final_zero_check_drop)

eap_merge_final = eap_merge_master[~eap_merge_master['unitid_year'].isin(eap_merge_final_zero_check_drop)]
# Out:
# year
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2007    1
# 2008    1
# 2009    2
# 2010    1
# 2011    1
# 2012    1
# 2015    3
# 2017    1
# 2018    3
# 2021    1
# Name: unitid, dtype: int64
# ['247922_2003', '247922_2004', '247922_2005', '247922_2006', '247922_2007', '369774_2008', '364122_2009', '453932_2009', '364122_2010', '364122_2011', '364122_2012', '181756_2015', '479585_2015', '479664_2015', '490470_2017', '445391_2018', '482343_2018', '490771_2018', '482486_2021']

# %%
eap_merge_final.info()

#eap_merge_final['total staff check'] = eap_merge_final['total staff ft'] + eap_merge_final['total staff pt']
#eap_merge_final_check = eap_merge_final[eap_merge_final['total staff check'] != eap_merge_final['total staff']]


#eap_2002_pivot['total_10_check'] = eap_2002_pivot['total_10_3'] + eap_2002_pivot['total_10_2']
#eap_2002_pivot_check = eap_2002_pivot[eap_2002_pivot['total_10_check'] != eap_2002_pivot['total_10_1']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136916 entries, 0 to 68106
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   unitid                           136916 non-null  int64
#  1   year                             136916 non-null  object
#  2   total staff                      136916 non-null  float64
#  3   total staff ft                   136916 non-null  float64
#  4   total staff pt                   136916 non-null  float64
#  5   total staff fte                  136916 non-null  float64
#  6   total instruction staff          136916 non-null  float64
#  7   total instruction ft             136916 non-null  float64
#  8   total instruction pt             136916 non-null  float64
#  9   total instruction staff fte      136916 non-null  float64
#  10  total non instruction            136916 non-null  float64
# ...

# %%
#eap_merge_zero_1 = eap_merge[eap_merge['total staff fte']==0]

#print(eap_merge_zero_1.groupby('year')['unitid'].count())

# %%
eap_merge_final.to_csv('/Users/ellenruthconnell/Documents/INFO_696/2_merge/staff_fte_master_2.csv',index=False)
